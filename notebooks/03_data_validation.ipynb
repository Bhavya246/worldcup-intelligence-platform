# %%
import pandas as pd

# %%
matches = pd.read_csv(r"E:\Python\worldcup-intelligence-platform\data\raw\international_results.csv")

# %%
matches.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
matches.shape
# Out:
# (49477, 9)

# %%
matches.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='str')

# %%
matches.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49477 entries, 0 to 49476
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        49477 non-null  str
#  1   home_team   49477 non-null  str
#  2   away_team   49477 non-null  str
#  3   home_score  49465 non-null  float64
#  4   away_score  49465 non-null  float64
#  5   tournament  49477 non-null  str
#  6   city        49477 non-null  str
#  7   country     49477 non-null  str
#  8   neutral     49477 non-null  bool
# dtypes: bool(1), float64(2), str(6)
# memory usage: 3.1 MB

# %%
matches.isnull().sum()
# Out:
# date           0
# home_team      0
# away_team      0
# home_score    12
# away_score    12
# tournament     0
# city           0
# country        0
# neutral        0
# dtype: int64

# %%
matches.describe(include="all")
# Out:
#               date home_team away_team    home_score    away_score tournament  \
# count        49477     49477     49477  49465.000000  49465.000000      49477
# unique       16471       327       321           NaN           NaN        200
# top     2012-02-29    Brazil   Uruguay           NaN           NaN   Friendly
# freq            66       616       585           NaN           NaN      18388
# mean           NaN       NaN       NaN      1.757404      1.181785        NaN
# std            NaN       NaN       NaN      1.774147      1.401717        NaN
# min            NaN       NaN       NaN      0.000000      0.000000        NaN
# 25%            NaN       NaN       NaN      1.000000      0.000000        NaN
# 50%            NaN       NaN       NaN      1.000000      1.000000        NaN
# 75%            NaN       NaN       NaN      2.000000      2.000000        NaN
# max            NaN       NaN       NaN     31.000000     21.000000        NaN
#
# ...

# %%
matches.duplicated().sum()
# Out:
# np.int64(0)

# %%
matches[matches["home_score"].isna()]
# Out:
#              date    home_team     away_team  home_score  away_score  \
# 49465  2026-06-26        Egypt          Iran         NaN         NaN
# 49466  2026-06-26  New Zealand       Belgium         NaN         NaN
# 49467  2026-06-26   Cape Verde  Saudi Arabia         NaN         NaN
# 49468  2026-06-26      Uruguay         Spain         NaN         NaN
# 49469  2026-06-26       Norway        France         NaN         NaN
# 49470  2026-06-26      Senegal          Iraq         NaN         NaN
# 49471  2026-06-27      Algeria       Austria         NaN         NaN
# 49472  2026-06-27       Jordan     Argentina         NaN         NaN
# 49473  2026-06-27     Colombia      Portugal         NaN         NaN
# 49474  2026-06-27     DR Congo    Uzbekistan         NaN         NaN
# 49475  2026-06-27       Panama       England         NaN         NaN
# 49476  2026-06-27      Croatia         Ghana         NaN         NaN
#
#            tournament             city        country  neutral
# ...

# %%
matches["date"].is_monotonic_increasing
# Out:
# False

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["date"].is_monotonic_increasing
# Out:
# False

# %%
matches.sort_values("date").head()
# Out:
#         date home_team away_team  home_score  away_score tournament     city  \
# 0 1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1 1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2 1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3 1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4 1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
matches.sort_values("date").tail()
# Out:
#             date home_team  away_team  home_score  away_score      tournament  \
# 49473 2026-06-27  Colombia   Portugal         NaN         NaN  FIFA World Cup
# 49475 2026-06-27    Panama    England         NaN         NaN  FIFA World Cup
# 49471 2026-06-27   Algeria    Austria         NaN         NaN  FIFA World Cup
# 49472 2026-06-27    Jordan  Argentina         NaN         NaN  FIFA World Cup
# 49476 2026-06-27   Croatia      Ghana         NaN         NaN  FIFA World Cup
#
#                   city        country  neutral
# 49473    Miami Gardens  United States     True
# 49475  East Rutherford  United States     True
# 49471      Kansas City  United States     True
# 49472        Arlington  United States     True
# 49476     Philadelphia  United States     True

# %%
START_YEAR = "2000-01-01"

# %%
matches["date"] = pd.to_datetime(matches["date"])

matches = matches.sort_values("date")

matches = matches[matches["date"] >= START_YEAR]

# %%
matches.shape
# Out:
# (25415, 9)

# %%
matches.dtypes
# Out:
# date          datetime64[us]
# home_team                str
# away_team                str
# home_score           float64
# away_score           float64
# tournament               str
# city                     str
# country                  str
# neutral                 bool
# dtype: object

# %%
matches = matches.dropna(subset=["home_score", "away_score"])

# %%
matches.shape
# Out:
# (25403, 9)

# %%
matches.isnull().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
matches["home_score"] = matches["home_score"].astype(int)
matches["away_score"] = matches["away_score"].astype(int)

# %%
matches.dtypes
# Out:
# date          datetime64[us]
# home_team                str
# away_team                str
# home_score             int64
# away_score             int64
# tournament               str
# city                     str
# country                  str
# neutral                 bool
# dtype: object

# %%
matches.to_csv(
    r"E:\Python\worldcup-intelligence-platform\data\raw\clean_matches.csv",
    index=False
)
