# %% [markdown]
# # 02 - Understanding Elo Ratings
#
# Author: Bhavya Arora
#
# Project: WorldCup Intelligence Platform

# %% [markdown]
# Argentina (2100)
#
# beats
#
# Japan (1850)
#
# ↓
#
# Small Elo increase

# %% [markdown]
# Japan (1850)
#
# beats
#
# Argentina (2100)
#
# ↓
#
# Large Elo increase

# %% [markdown]
# New Rating = Old Rating + K × (Actual − Expected)

# %% [markdown]
# WorldCup Elo v1
# ----------------
# ✓ Standard Elo
# ✓ Goal Difference
#
# WorldCup Elo v2
# ----------------
# ✓ Tournament Importance
# ✓ Host Advantage
#
# WorldCup Elo v3
# ----------------
# ✓ Recent Form
# ✓ Dynamic K-Factor
#
# WorldCup Elo v4
# ----------------
# Research Features

# %% [markdown]
# ## Reflection
#
# Today I learned:
#
# - Why Elo is better than raw rankings.
# - Why ratings should evolve after every match.
# - Why feature engineering begins before machine learning.
# - Why I want to build my own WorldCup Elo instead of downloading ratings.

# %%
ratings = {
    "Argentina": 2100,
    "France": 2050,
    "Brazil": 2080,
    "Japan": 1850
}

# %%
ratings["Argentina"]
# Out:
# 2100

# %%
ratings["Japan"]
# Out:
# 1850

# %%
ratings["Argentina"] += 10

# %%
ratings["Argentina"] += 10
# Out:
# {'Argentina': 2110, 'France': 2050, 'Brazil': 2080, 'Japan': 1850}
